# %%
#importing required library
import pandas as pd

#importing covid 19 data set
df = pd.read_csv("covid_19_data.csv")

#viewing the data set
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
#check data size
df.shape
print("This data set has {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# This data set has 306429 rows and 8 columns

# %%
#check what variables (data) we are going to analyze
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
#check what kinds of variable types are included
df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
## check the number of non-null values in each column
df.count()
# Out:
# SNo                306429
# ObservationDate    306429
# Province/State     228326
# Country/Region     306429
# Last Update        306429
# Confirmed          306429
# Deaths             306429
# Recovered          306429
# dtype: int64

# %%
#check the number of missing values in each column
df.isnull().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78103
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
#checking the percentage of missing values of each column
df.isnull().sum()/df.shape[0]
# Out:
# SNo                0.000000
# ObservationDate    0.000000
# Province/State     0.254881
# Country/Region     0.000000
# Last Update        0.000000
# Confirmed          0.000000
# Deaths             0.000000
# Recovered          0.000000
# dtype: float64

# %%
# Checking the varibles that present null values the most
(df.isnull().sum()/df.shape[0]).sort_values(ascending = False)[0:11]
# Out:
# Province/State     0.254881
# SNo                0.000000
# ObservationDate    0.000000
# Country/Region     0.000000
# Last Update        0.000000
# Confirmed          0.000000
# Deaths             0.000000
# Recovered          0.000000
# dtype: float64

# %%
#Checking the variables that present null values the least
(df.isnull().sum()/df.shape[0]).sort_values(ascending=True) [0:11]
# Out:
# SNo                0.000000
# ObservationDate    0.000000
# Country/Region     0.000000
# Last Update        0.000000
# Deaths             0.000000
# Confirmed          0.000000
# Recovered          0.000000
# Province/State     0.254881
# dtype: float64

# %%
#SHOW the number of Confirmed,Deaths and recovered cases in each region.
cases_by_region = df.groupby('Country/Region')[['Confirmed', 'Deaths', 'Recovered']].sum()

cases_by_region
# Out:
#                                  Confirmed    Deaths   Recovered
# Country/Region
#  Azerbaijan                            1.0       0.0         0.0
# ('St. Martin',)                        2.0       0.0         0.0
# Afghanistan                     17026442.0  669075.0  13464399.0
# Albania                         19768869.0  375955.0  13945256.0
# Algeria                         27684358.0  834464.0  18959299.0
# ...                                    ...       ...         ...
# West Bank and Gaza              41819444.0  440378.0  37003116.0
# Yemen                             962066.0  237613.0    506523.0
# Zambia                          13493953.0  205990.0  12625626.0
# Zimbabwe                         6484581.0  237234.0   5594887.0
# occupied Palestinian territory        25.0       0.0         0.0
#
# [229 rows x 3 columns]

# %%
df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=True)
# Out:
# Country/Region
# China              0.000000e+00
#  Azerbaijan        1.000000e+00
# Cape Verde         1.000000e+00
# Channel Islands    1.000000e+00
# East Timor         1.000000e+00
#                        ...
# France             8.551890e+08
# Russia             9.305488e+08
# Brazil             2.653588e+09
# India              3.226768e+09
# US                 6.049146e+09
# Name: Confirmed, Length: 229, dtype: float64

# %%
#Remove all the records where confirmed cases is less than 10

df=df[~(df['Confirmed']<10)]
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 1            2      01/22/2020            Beijing  Mainland China
# 5            6      01/22/2020          Guangdong  Mainland China
# 13          14      01/22/2020              Hubei  Mainland China
# 34          35      01/22/2020           Zhejiang  Mainland China
# 41          42      01/23/2020            Beijing  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 1           1/22/2020 17:00       14.0     0.0        0.0
# ...

# %%
#Remove all the records where confirmed cases is less than 10
df=df[~(df['Confirmed']<10)]
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 1            2      01/22/2020            Beijing  Mainland China
# 5            6      01/22/2020          Guangdong  Mainland China
# 13          14      01/22/2020              Hubei  Mainland China
# 34          35      01/22/2020           Zhejiang  Mainland China
# 41          42      01/23/2020            Beijing  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 1           1/22/2020 17:00       14.0     0.0        0.0
# ...

# %%
#INwhich region,max number of confirmed cases were recorded?
df.groupby("Country/Region").Confirmed.sum().sort_values(ascending=False).head(10)
# Out:
# Country/Region
# US         6.049144e+09
# India      3.226768e+09
# Brazil     2.653588e+09
# Russia     9.305488e+08
# France     8.551871e+08
# UK         7.837912e+08
# Spain      6.491117e+08
# Italy      6.366942e+08
# Turkey     6.189409e+08
# Germany    5.241668e+08
# Name: Confirmed, dtype: float64

# %%
#in which region, min number of death cases were recorded?
df.groupby("Country/Region").Deaths.sum().sort_values(ascending=True).head(10)
# Out:
# Country/Region
# Dominica                 0.0
# French Guiana            0.0
# Holy See                 0.0
# Guadeloupe               0.0
# Macau                    0.0
# Reunion                  0.0
# Saint Kitts and Nevis    0.0
# Palestine                0.0
# Republic of Ireland      0.0
# Solomon Islands          0.0
# Name: Deaths, dtype: float64

# %%
#How many confirmed,deaths and recovered cases were reported from India
df[df['Country/Region'] == 'India']
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 3372      3373      03/04/2020            NaN          India
# 3537      3538      03/05/2020            NaN          India
# 3712      3713      03/06/2020            NaN          India
# 3915      3916      03/07/2020            NaN          India
# 4143      4144      03/08/2020            NaN          India
# ...        ...             ...            ...            ...
# 306334  306335      05/29/2021      Telangana          India
# 306351  306352      05/29/2021        Tripura          India
# 306377  306378      05/29/2021  Uttar Pradesh          India
# 306378  306379      05/29/2021    Uttarakhand          India
# 306406  306407      05/29/2021    West Bengal          India
#
#                 Last Update  Confirmed   Deaths  Recovered
# 3372    2020-03-04T12:33:03       28.0      0.0        3.0
# 3537    2020-03-05T13:53:03       30.0      0.0        3.0
# ...

# %%
#Sort the entire data wrt no of recovered cases in descending order
df.sort_values(by=['Recovered'],ascending=False)
# Out:
#            SNo ObservationDate Province/State  Country/Region  \
# 306127  306128      05/29/2021    Maharashtra           India
# 305362  305363      05/28/2021    Maharashtra           India
# 304597  304598      05/27/2021    Maharashtra           India
# 303832  303833      05/26/2021    Maharashtra           India
# 303067  303068      05/25/2021    Maharashtra           India
# ...        ...             ...            ...             ...
# 141        142      01/25/2020       Shandong  Mainland China
# 142        143      01/25/2020        Guangxi  Mainland China
# 143        144      01/25/2020         Hainan  Mainland China
# 144        145      01/25/2020        Jiangxi  Mainland China
# 11415    11416      04/02/2020  New Hampshire              US
#
#                 Last Update  Confirmed   Deaths  Recovered
# 306127  2021-05-30 04:20:55  5713215.0  94030.0  5339838.0
# 305362  2021-05-29 04:20:41  5692920.0  93198.0  5307874.0
# ...
